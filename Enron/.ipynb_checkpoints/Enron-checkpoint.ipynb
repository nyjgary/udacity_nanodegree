# %%
import sys
import pickle
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

# sys.path.append("../tools/")

from feature_format import featureFormat, targetFeatureSplit
from tester import dump_classifier_and_data

### Load the dictionary containing the dataset
with open("final_project_dataset.pkl", "r") as data_file:
    data_dict = pickle.load(data_file)
del data_dict['TOTAL'] # Not sure why this was in the dataset in the first place, but deleting this before proceeding further
df = pd.DataFrame.from_dict(data_dict,orient='index')

# %%
### Get basic statistics about data set 

## No. of records 
print 'Total # of records: ' + str(len(df))
print 'Total # of POI: ' + str(sum(df['poi']==True))

## Missing values by variable 
df.replace("NaN", np.nan, inplace=True) # properly encode null values 
df.isnull().sum()
# Out:
# Total # of records: 145
# Total # of POI: 18
# salary                        51
# to_messages                   59
# deferral_payments            107
# total_payments                21
# exercised_stock_options       44
# bonus                         64
# restricted_stock              36
# shared_receipt_with_poi       59
# restricted_stock_deferred    128
# total_stock_value             20
# expenses                      51
# loan_advances                142
# from_messages                 59
# other                         53
# from_this_person_to_poi       59
# poi                            0
# director_fees                129
# deferred_income               97
# long_term_incentive           80
# email_address                 34
# from_poi_to_this_person       59
# dtype: int64

# %%
df[email_features].describe()
# Out:
#         to_messages  from_messages  from_this_person_to_poi  \
# count     86.000000      86.000000                86.000000
# mean    2073.860465     608.790698                41.232558
# std     2582.700981    1841.033949               100.073111
# min       57.000000      12.000000                 0.000000
# 25%      541.250000      22.750000                 1.000000
# 50%     1211.000000      41.000000                 8.000000
# 75%     2634.750000     145.500000                24.750000
# max    15149.000000   14368.000000               609.000000
#
#        from_poi_to_this_person  shared_receipt_with_poi
# count                86.000000                86.000000
# mean                 64.895349              1176.465116
# std                  86.979244              1178.317641
# min                   0.000000                 2.000000
# 25%                  10.000000               249.750000
# 50%                  35.000000               740.500000
# 75%                  72.250000              1888.250000
# max                 528.000000              5521.000000

# %%
# %matplotlib inline
plt.figure(figsize=(16,8))

email_features = ['to_messages', 'from_messages', 'from_this_person_to_poi', 'from_poi_to_this_person', 'shared_receipt_with_poi']
data = df[email_features]
data.dropna(inplace=True)

for i, j in zip(range(5), data.columns):
    plot_no = 231 + i 
    plt.subplot(plot_no)
    plt.hist(data[j], bins=20, color = (0.93,0.4,0.36))
    plt.title(j)

plt.tight_layout()
# Out:
# /Users/garyng/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df[financial_features1].describe()
# Out:
#                salary  deferral_payments  total_payments  \
# count       94.000000          38.000000    1.240000e+02
# mean    284087.542553      841602.526316    2.623421e+06
# std     177131.115377     1289322.626180    9.488106e+06
# min        477.000000     -102500.000000    1.480000e+02
# 25%     211802.000000       79644.500000    3.863802e+05
# 50%     258741.000000      221063.500000    1.100246e+06
# 75%     308606.500000      867211.250000    2.084663e+06
# max    1111258.000000     6426990.000000    1.035598e+08
#
#        exercised_stock_options           bonus
# count               101.000000       81.000000
# mean            2959559.257426  1201773.074074
# std             5499449.598994  1441679.438330
# min                3285.000000    70000.000000
# 25%              506765.000000   425000.000000
# 50%             1297049.000000   750000.000000
# 75%             2542813.000000  1200000.000000
# max            34348384.000000  8000000.000000

# %%
### Divide features into groups for scatterplot matrices 

financial_features1 = ['salary', 'deferral_payments', 'total_payments', 'exercised_stock_options', 'bonus'] 
financial_features2 = ['salary','restricted_stock', 'restricted_stock_deferred', 'total_stock_value', 'deferred_income','long_term_incentive']
financial_features3 = ['salary','expenses','loan_advances','director_fees','other']

# %%
### Scatterplot matrix for email features

% pylab inline 

from pandas.tools.plotting import scatter_matrix
scatter_matrix(df[email_features], alpha=0.2, figsize=(16, 16), diagonal='kde')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['axes']
# `%matplotlib` prevents importing * from pylab and numpy
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119fa6910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aa96f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ab0fe50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ab7b590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11abfd550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11ab9e8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aced550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ae70750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11aed0f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11af52f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11afacc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b838e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b8bcd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b929d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b9acbd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11bb12c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bb93ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bbfd810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bd85950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11be08810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11be772d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11befa190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bf5e210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bfe11d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c019350>]], dtype=object)

# %%
### Analyze specific email scatterplots of interest

fig, axes = plt.subplots(nrows=3, ncols=1)
fig.set_figheight(18)
fig.set_figwidth(6)

df_to_poi = df[['from_this_person_to_poi','from_messages','poi']].dropna()
df_to_poi.plot(kind='scatter',x='from_messages',y='from_this_person_to_poi',ax=axes[0])

df_from_poi = df[['from_poi_to_this_person','to_messages']].dropna()
df_from_poi.plot(kind='scatter',x='to_messages',y='from_poi_to_this_person',ax=axes[1])

df_shared = df[['shared_receipt_with_poi','to_messages']].dropna()
df_shared.plot(kind='scatter',x='to_messages',y='shared_receipt_with_poi',ax=axes[2])

# %%
### Scatterplot matrix for financial features (1) 

scatter_matrix(df[financial_features1], alpha=0.2, figsize=(16, 16), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c80a210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d4fa610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d57a4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d5ddf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d65ff10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d600110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d74ff10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d7dd150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11da51990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dad2950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11db2b650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dbb9850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dc3b710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dca9710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dd2c5d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11dd90610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11de134d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dda9cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e004410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e0882d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e0eac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e26db50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e2d1bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e353b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e361f50>]], dtype=object)

# %%
### Scatterplot matrix for financial features (2) 

scatter_matrix(df[financial_features2], alpha=0.2, figsize=(16, 16), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11f460a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f4a4ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f525f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f5af0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f6302d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f5ce550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11f722190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f7a3050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121669850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1216eb810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121850790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1218d2750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x121a56610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121ac3850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121b47710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121bad690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121c2e550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121bc4d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x121d1f490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121da2350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e4050d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x121de5290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122040f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1220d4110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x122249f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1222b8a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12233c910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1223a1990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122423950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12245aad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x122515850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122598710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1225fa890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12267e750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1226e6490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1227715d0>]], dtype=object)

# %%
### Scatterplot matrix for financial features (3) 

scatter_matrix(df[financial_features3], alpha=0.2, figsize=(16, 16), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x123128850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123a60850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123ae9490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123b44510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123bc19d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x123b6e790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123cb35d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123d36490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123d99c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123e19c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x123e7fbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123f01b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123f84a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x123ff3c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124874b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1248daad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124a5b990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1248f3e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124c4e8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124cd1790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x124d3f190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124dc3050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124e270d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124ea9090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124edf210>]], dtype=object)

# %%
### Analyze specific financial scatterplots of interest

fig, axes = plt.subplots(nrows=3, ncols=2)
fig.set_figheight(18)
fig.set_figwidth(12)

df_salary_total_payments = df[['salary','total_payments']].dropna()
df_salary_total_payments.plot(kind='scatter',x='salary',y='total_payments',ax=axes[0,0])

df_salary_LT_incentive = df[['salary','long_term_incentive']].dropna()
df_salary_LT_incentive.plot(kind='scatter',x='salary',y='long_term_incentive',ax=axes[0,1])

df_salary_bonus = df[['salary','bonus']].dropna()
df_salary_bonus.plot(kind='scatter',x='salary',y='bonus',ax=axes[1,0])

df_salary_bonus = df[['salary','bonus']].dropna()
df_salary_bonus.plot(kind='scatter',x='salary',y='bonus',ax=axes[1,0])

# %% [markdown]
# # References

# %% [markdown]
# http://stackoverflow.com/questions/7941207/is-there-a-function-to-make-scatterplot-matrices-in-matplotlib
